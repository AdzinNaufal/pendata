# %% [markdown]
# # Fuzzy C-Mean Clustering

# %% [markdown]
# ## Konsep dasar Fuzzy C-Mean Clustering

# %% [markdown]
# ## Algoritma Fuzzy C-Mean Clustering

# %% [markdown]
# ## Contoh manual perhitungan
